# %% [markdown]
# 고양이 수염 스티커 만들기
# ===
#
# 얼굴인식 카메라앱을 만들어 보기
# 얼굴을 인식하여 고양이 수염 스티커를 붙어보기

# %% [markdown]
# ## 1. 이미지 준비하기
#
# 고양이 수염 이미지는
# https://www.flaticon.com/free-icon/cat-whiskers_24674?term=cat%20nose&page=1&position=1#
# 에서 구할 수 있습니다.

# %%
# 이미지 처리 관련 패키지들 설치
# !pip install opencv-python
# !pip install cmake
# !pip install dlib

# %%
# 필요한 라이브러리를 불러오기
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
# 이미지 읽기
import os

my_image_path = os.getenv('HOME')+'/aiffel/Exploration/E3/images/img1.png'
img_bgr = cv2.imread(my_image_path)    # OpenCV로 이미지를 읽어서
img_bgr = cv2.resize(img_bgr, (640, 480))    # 640x480의 크기로 Resize
img_show = img_bgr.copy()      # 출력용 이미지 별도 보관
plt.imshow(img_bgr)
plt.show()

# %% [markdown]
# - matplotlib, dlib 등의 이미지 라이브러리는 모두 이미지 채널을 RGB(빨강, 녹색, 파랑) 순으로 사용합니다. 그런데 opencv는 예외적으로 BGR(파랑, 녹색, 빨강)을 사용하기 때문에 색상 순서를 변경해 주어야 합니다.

# %%
# opencv가 사용하는 BGR --> 원래 색상 RGB로 변경
img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)
plt.show()

# %% [markdown]
# ## 2. 얼굴 검출 face detection

# %% [markdown]
# Object detection 기술을 이용해서 얼굴의 위치를 찾습니다. 학습 없이 공개되어 있는 패키지(dlib)를 사용합니다.
#
# dlib 의 face detector는 HOG(Histogram of Oriented Gradient) feature를 사용해서 SVM(Support Vector Machine)의 sliding window로 얼굴을 찾습니다.

# %%
# dlib을 활용해 hog detector를 선언
import dlib
detector_hog = dlib.get_frontal_face_detector()

# %%
# detector를 이용해서 먼저 얼굴의 bounding box를 추출
dlib_rects = detector_hog(img_rgb, 1)

# %% [markdown]
# - detector_hog(rgb image, num of img pyramid)
#     detector_hog의 첫 번째 파라미터는 rgb 이미지입니다.
#     두 번째 파라미터는 이미지 피라미드의 수입니다.
#
#     *이미지 피라미드 :
# upsampling 방법을 통해 크기를 키우는 것.
# 이미지 피라미드에서 얼굴을 다시 검출하면 작게 촬영된 얼굴을 크게 볼 수 있기 때문에 더 정확한 검출이 가능

# %%
# 찾은 얼굴영역 좌표 찍어보기
print(dlib_rects)
# Out:
# rectangles[[(221, 57) (407, 242)]]

# %% [markdown]
# - dlib detector는 dlib.rectangles 타입의 객체를 반환합니다.
# - dlib.rectangles는 dlib.rectangle 객체의 배열 형태로 이루어져 있습니다.
# - dlib.rectangle 객체는 left(), top(), right(), bottom(), height(), width() 등의 멤버 함수를 포함하고 있습니다.

# %%
# 찾은 얼굴영역(dlib_rects)을 green으로 화면에 출력
for dlib_rect in dlib_rects:
    l = dlib_rect.left()
    t = dlib_rect.top()
    r = dlib_rect.right()
    b = dlib_rect.bottom()
    
    cv2.rectangle(img_show, (l,t), (r,b), (0,255,0), 2, lineType=cv2.LINE_AA)
    
img_show_rgb = cv2.cvtColor(img_show, cv2.COLOR_BGR2RGB)
plt.imshow(img_show_rgb)
plt.show()

# %% [markdown]
# - cv2.rectangle(img, start, end, color, thickness)
#
#     Parameters :
#      img – 그림을 그릴 이미지
#      start – 시작 좌표
#      end – 종료 좌표
#      color – BGR형태의 Color (0, 255, 0) -> Green
#      thickness (int) – 선의 두께. pixel

# %% [markdown]
# ## 3. 얼굴 랜드마크 face landmark

# %%
# 저장한 landmark 모델을 불러오기
model_path = os.getenv('HOME')+'/aiffel/Exploration/E3/models/shape_predictor_68_face_landmarks.dat'
landmark_predictor = dlib.shape_predictor(model_path)

# %%
# 이미지의 68개의 랜드마크가 list_landmarks에 저장
list_landmarks = []
for dlib_rect in dlib_rects:
    points = landmark_predictor(img_rgb, dlib_rect)
    list_points = list(map(lambda p: (p.x, p.y), points.parts()))
    list_landmarks.append(list_points)
    
print(len(list_landmarks[0]))
# Out:
# 68

# %% [markdown]
# - landmark_predictor는 RGB 이미지와 dlib.rectangle을 입력받아 dlib.full_object_detection를 반환합니다.
# - points는 dlib.full_object_detection의 객체이기 때문에 parts() 함수로 개별 위치에 접근할 수 있습니다. (x, y) 형태로 접근할 수 있도록 변환해 주었습니다.
# - list_points는 tuple (x, y) 68개로 이루어진 리스트가 됩니다. 이미지에서 찾아진 얼굴 개수마다 반복하면 list_landmark에 68개의 랜드마크가 얼굴 개수만큼 저장됩니다.
#
# \* dlib.full_object_detection
# http://dlib.net/python/index.html#dlib.full_object_detection

# %%
# 랜드마크를 yellow로 이미지에 출력
i=0
for landmark in list_landmarks:
    for point in landmark:
        cv2.circle(img_show, point, 2, (0, 255, 255), -1)
        cv2.putText(img_show, str(i), point, cv2.FONT_HERSHEY_SIMPLEX, 0.3, (255,0,0), 1) # 랜드마크 번호 출력
        i+=1
        
img_show_rgb = cv2.cvtColor(img_show, cv2.COLOR_BGR2RGB)
plt.imshow(img_show_rgb)
plt.show()

# %% [markdown]
# - cv2.circle(img, center, radian, color, thickness)
# - cv2.putText(img, text, org, fontFace, fontSacle, color, thickness)

# %% [markdown]
# ## 4. 스티커 적용하기

# %% [markdown]
# ### 스티커 적용 위치 확인하기
#
# 고양이 수염이 적용 될 코 위치를 landmark를 사용하여 계산합니다.
# 코는 랜드마크(30) 있다는 점을 이용합니다.

# %%
# 좌표를 먼저 확인
for dlib_rect, landmark in zip(dlib_rects, list_landmarks):
    print (landmark[30]) # nose center index : 30
    x = landmark[30][0]
    y = landmark[30][1]
    w = dlib_rect.width() 
    h = dlib_rect.width() // 3
    print ('(x,y) : (%d,%d)'%(x,y))
    print ('(w,h) : (%d,%d)'%(w,h))
# Out:
# (316, 159)
# (x,y) : (316,159)
# (w,h) : (187,62)

# %%
# 준비해 둔 스티커 이미지를 읽어서 출력해보기
import os
sticker_path = os.getenv('HOME')+'/aiffel/Exploration/E3/images/cat-whiskers.png'
img_sticker = cv2.imread(sticker_path)
img_sticker = cv2.resize(img_sticker, (w,h))
print (img_sticker.shape)

plt.imshow(img_sticker)
plt.show()
# Out:
# (62, 187, 3)

# %% [markdown]
# - 고양이 수염 이미지를 읽고 윗 단계에서 계산한 크기(w,h)로 resize

# %%
# 원본 이미지에 스티커 이미지를 추가하기 위해서 x, y 좌표를 조정
# 이미지 시작점은 top-left 좌표
refined_x = x - w // 2 # left
refined_y = y - h // 2 # top
print ('(x,y) : (%d,%d)'%(refined_x, refined_y))
# Out:
# (x,y) : (223,128)

# %%
img_show.shape
# Out:
# (480, 640, 3)

# %%
# 원본 이미지에 스티커를 적용
sticker_area = img_show[refined_y:refined_y+img_sticker.shape[0], refined_x:refined_x+img_sticker.shape[1]]
img_show[refined_y:refined_y+img_sticker.shape[0], refined_x:refined_x+img_sticker.shape[1]] = \
        np.where(img_sticker==255, sticker_area, img_sticker).astype(np.uint8)

# 결과 이미지를 출력
plt.imshow(cv2.cvtColor(img_show, cv2.COLOR_BGR2RGB))
plt.show()

# %%
# bounding box와 landmark를 제거하고 최종 결과만 출력
sticker_area = img_bgr[refined_y:refined_y+img_sticker.shape[0], refined_x:refined_x+img_sticker.shape[1]]
img_bgr[refined_y:refined_y+img_sticker.shape[0], refined_x:refined_x+img_sticker.shape[1]] = \
        np.where(img_sticker==255, sticker_area, img_sticker).astype(np.uint8)

plt.imshow(cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# - 위의 이미지에서 face detection, facd landmark 검출이 잘 되어 고양이 수염도 잘 적용된 것을 볼 수 있다.

# %% [markdown]
# ## 5. 다른 이미지 적용해보기

# %% [markdown]
# ### 1) 다른 정면 사진

# %%
# 1. 이미지 읽어오기 
my_image_path = os.getenv('HOME')+'/aiffel/Exploration/E3/images/img2.png'
img_bgr = cv2.imread(my_image_path)    # OpenCV로 이미지를 읽어서
img_bgr = cv2.resize(img_bgr, (640, 480))    # 640x480의 크기로 Resize
img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB) # RGB로 변경

plt.imshow(img_rgb)
plt.show()

# %%
# 2. 얼굴의 bounding box를 추출
dlib_rects = detector_hog(img_rgb, 1)
print(dlib_rects)
# Out:
# rectangles[[(118, 76) (504, 461)]]

# %%
# 3. 얼굴 랜드마크 좌표 저장
list_landmarks = []
for dlib_rect in dlib_rects:
    points = landmark_predictor(img_rgb, dlib_rect)
    list_points = list(map(lambda p: (p.x, p.y), points.parts()))
    list_landmarks.append(list_points)

print(len(list_landmarks[0]))
# Out:
# 68

# %%
# 4. 스티커 적용하기 

# 좌표 확인
for dlib_rect, landmark in zip(dlib_rects, list_landmarks):
    print (landmark[30]) # nose center index : 30
    x = landmark[30][0]
    y = landmark[30][1]
    w = dlib_rect.width() 
    h = dlib_rect.width() // 3
    print ('(x,y) : (%d,%d)'%(x,y))
    print ('(w,h) : (%d,%d)'%(w,h))
    
refined_x = x - w // 2  # left
refined_y = y - h // 2  # top
print ('(x,y) : (%d,%d)'%(refined_x, refined_y))
# Out:
# (302, 266)
# (x,y) : (302,266)
# (w,h) : (387,129)
# (x,y) : (109,202)

# %%
# 스티커를 크기 맞춰주고 붙여주기 
sticker_path = os.getenv('HOME')+'/aiffel/Exploration/E3/images/cat-whiskers.png'
img_sticker = cv2.imread(sticker_path)
img_sticker = cv2.resize(img_sticker, (w,h))

sticker_area = img_bgr[refined_y:refined_y+img_sticker.shape[0], refined_x:refined_x+img_sticker.shape[1]]
img_bgr[refined_y:refined_y+img_sticker.shape[0], refined_x:refined_x+img_sticker.shape[1]] = \
        np.where(img_sticker==255, sticker_area, img_sticker).astype(np.uint8)
plt.imshow(cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# - 위의 다른 정면 사진에서도 잘 적용된 것을 볼 수 있다

# %% [markdown]
# ### 2) 다른 정면 사진 2

# %%
# 1. 이미지 읽어오기 
my_image_path = os.getenv('HOME')+'/aiffel/Exploration/E3/images/img3.png'
img_bgr = cv2.imread(my_image_path)    # OpenCV로 이미지를 읽어서
img_bgr = cv2.resize(img_bgr, (640, 480))    # 640x480의 크기로 Resize
img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB) # RGB로 변경

plt.imshow(img_rgb)
plt.show()

# %%
# 2. 얼굴의 bounding box를 추출
dlib_rects = detector_hog(img_rgb, 1)
print(dlib_rects)
# Out:
# rectangles[[(221, 118) (407, 304)]]

# %%
# 3. 얼굴 랜드마크 좌표 저장
list_landmarks = []
for dlib_rect in dlib_rects:
    points = landmark_predictor(img_rgb, dlib_rect)
    list_points = list(map(lambda p: (p.x, p.y), points.parts()))
    list_landmarks.append(list_points)

print(len(list_landmarks[0]))
# Out:
# 68

# %%
# 4. 스티커 적용하기 

# 좌표 확인
for dlib_rect, landmark in zip(dlib_rects, list_landmarks):
    print (landmark[30]) # nose center index : 30
    x = landmark[30][0]
    y = landmark[30][1]
    w = dlib_rect.width() 
    h = dlib_rect.width() // 3
    print ('(x,y) : (%d,%d)'%(x,y))
    print ('(w,h) : (%d,%d)'%(w,h))
    
refined_x = x - w // 2  # left
refined_y = y - h // 2  # top
print ('(x,y) : (%d,%d)'%(refined_x, refined_y))
# Out:
# (319, 213)
# (x,y) : (319,213)
# (w,h) : (187,62)
# (x,y) : (226,182)

# %%
# 스티커를 크기 맞춰주고 붙여주기 
sticker_path = os.getenv('HOME')+'/aiffel/Exploration/E3/images/cat-whiskers.png'
img_sticker = cv2.imread(sticker_path)
img_sticker = cv2.resize(img_sticker, (w,h))

sticker_area = img_bgr[refined_y:refined_y+img_sticker.shape[0], refined_x:refined_x+img_sticker.shape[1]]
img_bgr[refined_y:refined_y+img_sticker.shape[0], refined_x:refined_x+img_sticker.shape[1]] = \
        np.where(img_sticker==255, sticker_area, img_sticker).astype(np.uint8)
plt.imshow(cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# - 위의 이미지에서 face randmark는 잘 검출 되어 좌표는 잘 맞지만 ,
#     얼굴의 bounding box가 너무 좁게 되어 고양이 수염 길이 또한 짧은 것을 볼 수 있다.

# %% [markdown]
# ### 3) 얼굴에 뭐가 묻어 있는 사진

# %%
# 1. 이미지 읽어오기 
my_image_path = os.getenv('HOME')+'/aiffel/Exploration/E3/images/img4.png'
img_bgr = cv2.imread(my_image_path)    # OpenCV로 이미지를 읽어서
img_bgr = cv2.resize(img_bgr, (640, 480))    # 640x480의 크기로 Resize
img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB) # RGB로 변경

plt.imshow(img_rgb)
plt.show()

# %%
# 2. 얼굴의 bounding box를 추출
dlib_rects = detector_hog(img_rgb, 1)
print(dlib_rects)
# Out:
# rectangles[[(200, 142) (468, 409)]]

# %%
# 3. 얼굴 랜드마크 좌표 저장
list_landmarks = []
for dlib_rect in dlib_rects:
    points = landmark_predictor(img_rgb, dlib_rect)
    list_points = list(map(lambda p: (p.x, p.y), points.parts()))
    list_landmarks.append(list_points)

print(len(list_landmarks[0]))
# Out:
# 68

# %%
# 4. 스티커 적용하기 

# 좌표 확인
for dlib_rect, landmark in zip(dlib_rects, list_landmarks):
    print (landmark[30]) # nose center index : 30
    x = landmark[30][0]
    y = landmark[30][1]
    w = dlib_rect.width() 
    h = dlib_rect.width() // 3
    print ('(x,y) : (%d,%d)'%(x,y))
    print ('(w,h) : (%d,%d)'%(w,h))
    
refined_x = x - w // 2  # left
refined_y = y - h // 2  # top
print ('(x,y) : (%d,%d)'%(refined_x, refined_y))
# Out:
# (329, 259)
# (x,y) : (329,259)
# (w,h) : (269,89)
# (x,y) : (195,215)

# %%
# 스티커를 크기 맞춰주고 붙여주기 
sticker_path = os.getenv('HOME')+'/aiffel/Exploration/E3/images/cat-whiskers.png'
img_sticker = cv2.imread(sticker_path)
img_sticker = cv2.resize(img_sticker, (w,h))

sticker_area = img_bgr[refined_y:refined_y+img_sticker.shape[0], refined_x:refined_x+img_sticker.shape[1]]
img_bgr[refined_y:refined_y+img_sticker.shape[0], refined_x:refined_x+img_sticker.shape[1]] = \
        np.where(img_sticker==255, sticker_area, img_sticker).astype(np.uint8)
plt.imshow(cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# - 얼굴 수염 부분에 쉐이빙 폼이 묻어 있지만 ,
#     그럼에도 bounding box와 face randmark가 잘 수행되어 고양이 수염이 적용 되었다.

# %% [markdown]
# ### 4) 얼굴 인식 자체를 못하는 사진

# %%
# 1. 이미지 읽어오기 
my_image_path = os.getenv('HOME')+'/aiffel/Exploration/E3/images/img5.png'
img_bgr = cv2.imread(my_image_path)    # OpenCV로 이미지를 읽어서
img_bgr = cv2.resize(img_bgr, (640, 480))    # 640x480의 크기로 Resize
img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB) # RGB로 변경

plt.imshow(img_rgb)
plt.show()

# %%
# 2. 얼굴의 bounding box를 추출
dlib_rects = detector_hog(img_rgb, 1)
print(dlib_rects)
# Out:
# rectangles[]

# %% [markdown]
# - 이미지 밝기가 너무 밝아서 얼굴을 아예 인식하지 못하는지 dlib_rects가 비어있다.

# %% [markdown]
# ### 5) 안경을 쓴 사진

# %%
# 1. 이미지 읽어오기 
my_image_path = os.getenv('HOME')+'/aiffel/Exploration/E3/images/img6.png'
img_bgr = cv2.imread(my_image_path)    # OpenCV로 이미지를 읽어서
img_bgr = cv2.resize(img_bgr, (640, 480))    # 640x480의 크기로 Resize
img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB) # RGB로 변경

plt.imshow(img_rgb)
plt.show()

# %%
# 2. 얼굴의 bounding box를 추출
dlib_rects = detector_hog(img_rgb, 1)
print(dlib_rects)
# Out:
# rectangles[]

# %% [markdown]
# - 안경을 쓴 경우에 안경에 비친 빛 때문인지 얼굴 자체를 인식하지 못하였다.

# %% [markdown]
# ### 6) 눈을 감은 사진

# %%
# 1. 이미지 읽어오기 
my_image_path = os.getenv('HOME')+'/aiffel/Exploration/E3/images/img7.png'
img_bgr = cv2.imread(my_image_path)    # OpenCV로 이미지를 읽어서
img_bgr = cv2.resize(img_bgr, (640, 480))    # 640x480의 크기로 Resize
img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB) # RGB로 변경

plt.imshow(img_rgb)
plt.show()

# %%
# 2. 얼굴의 bounding box를 추출
dlib_rects = detector_hog(img_rgb, 1)
print(dlib_rects)
# Out:
# rectangles[]

# %% [markdown]
# - 눈을 감은 경우에도 얼굴을 인식하지 못하였다.

# %% [markdown]
# ### 7) 얼굴이 여러개인 사진

# %%
# 1. 이미지 읽어오기 
my_image_path = os.getenv('HOME')+'/aiffel/Exploration/E3/images/img8.png'
img_bgr = cv2.imread(my_image_path)    # OpenCV로 이미지를 읽어서
img_bgr = cv2.resize(img_bgr, (640, 480))    # 640x480의 크기로 Resize
img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB) # RGB로 변경

plt.imshow(img_rgb)
plt.show()

# %%
# 2. 얼굴의 bounding box를 추출
dlib_rects = detector_hog(img_rgb, 1)
print(dlib_rects)
# Out:
# rectangles[]

# %% [markdown]
# - 얼굴이 여러개 있는 경우도 얼굴을 인식하지 못하였다.

# %% [markdown]
# ## 회고
#
# - 나만의 카메라앱 기능 구현을 완수하였다.
#     이미지 원본에 고양이 스티커 사진이 정상적으로 합성되었다.
#
#
# - 스티커 이미지를 비교적 정확한 원본 위치에 반영하였다.
#     정확한 좌표계산을 통해 고양이 수염의 위치를 잡아 대부분 원본 얼굴에 잘 어울리게 출력되었지만
#     얼굴 bounding box가 잘못 정해지는 경우에는 수염의 크기가 조절 되었고,
#     face landmark 인식을 잘못 하는 경우에는 위치가 살짝 조절 되었다.
#
#
# - 카메라 스티커앱을 다양한 원본이미지에 적용했을 때의 문제점을 체계적으로 분석하려 하였다.
#     다양한 변수에 따른 영향도 알아보려 여러 시도를 하였으나 문제점과 해결 방법을 제대로 분석하지는 못하였다.
