# %% [markdown]
#  8.인물 사진을 만들어보자
# =======
#
# DeepLab이라는 세그멘테이션 모델 사용하는 딥러닝을 적용하여 핸드폰 인물 사진 모드를 따라 해 보기
#
#
# -21.10.26-

# %% [markdown]
# ## 1. 인물 사진 만들어보기

# %% [markdown]
# ### 1) 사진 준비하기

# %%
import cv2
import numpy as np
import os
import tarfile
import urllib

from matplotlib import pyplot as plt
import tensorflow as tf

# %%
import os
person_path = os.getenv('HOME')+'/aiffel/Exploration/E8/images/person.png'  # 본인이 선택한 이미지의 경로에 맞게 바꿔 주세요. 
person_orig = cv2.imread(person_path) 
print (person_orig.shape)
# Out:
# (574, 430, 3)

# %% [markdown]
# ### 2) 시맨틱 세그멘테이션 다뤄보기
#
# 세그멘테이션 문제에는 FCN, SegNet, U-Net 등 많은 모델이 사용됩니다. 그중에서 DeepLab이라는 세그멘테이션 모델을 만들고 모델에 이미지를 입력하겠습니다.

# %% [markdown]
# ### DeepLab 모델을 준비
#
# 구글에서 제공하는 모델 구조를 그대로 가지고 와 DeepLabModel 클래스를 만들겠습니다.

# %%
class DeepLabModel(object):
    INPUT_TENSOR_NAME = 'ImageTensor:0'
    OUTPUT_TENSOR_NAME = 'SemanticPredictions:0'
    INPUT_SIZE = 513
    FROZEN_GRAPH_NAME = 'frozen_inference_graph'

    # __init__()에서 모델 구조를 직접 구현하는 대신, tar file에서 읽어들인 그래프구조 graph_def를 
    # tf.compat.v1.import_graph_def를 통해 불러들여 활용하게 됩니다. 
    def __init__(self, tarball_path):
        self.graph = tf.Graph()
        graph_def = None
        tar_file = tarfile.open(tarball_path)
        for tar_info in tar_file.getmembers():
            if self.FROZEN_GRAPH_NAME in os.path.basename(tar_info.name):
                file_handle = tar_file.extractfile(tar_info)
                graph_def = tf.compat.v1.GraphDef.FromString(file_handle.read())
                break
        tar_file.close()

        with self.graph.as_default():
            tf.compat.v1.import_graph_def(graph_def, name='')

        self.sess = tf.compat.v1.Session(graph=self.graph)

    # 이미지를 전처리하여 Tensorflow 입력으로 사용 가능한 shape의 Numpy Array로 변환합니다.
    def preprocess(self, img_orig):
        height, width = img_orig.shape[:2]
        resize_ratio = 1.0 * self.INPUT_SIZE / max(width, height)
        target_size = (int(resize_ratio * width), int(resize_ratio * height))
        resized_image = cv2.resize(img_orig, target_size)
        resized_rgb = cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB)
        img_input = resized_rgb
        return img_input
    
    
    # 실제로 세그멘테이션 실행
    def run(self, image):
        img_input = self.preprocess(image)

        # Tensorflow V1에서는 model(input) 방식이 아니라 sess.run(feed_dict={input...}) 방식을 활용합니다.
        batch_seg_map = self.sess.run(
            self.OUTPUT_TENSOR_NAME,
            feed_dict={self.INPUT_TENSOR_NAME: [img_input]})

        seg_map = batch_seg_map[0]
        return cv2.cvtColor(img_input, cv2.COLOR_RGB2BGR), seg_map

# %% [markdown]
# - preprocess()는 전처리, run()은 실제로 세그멘테이션을 하는 함수입니다. 먼저 input tensor를 만들기 위해 preprocess() 함수에서 이미지를 전처리 합니다.
#
# - 모델이 받는 입력 크기가 정해져 있으므로 이에 따라 적절한 크기로 resize 하고, OpenCV의 디폴트 BGR 채널 순서를 텐서플로우에 맞는 RGB로 수정합니다.
#
# - 전처리된 이미지는 run() 함수에서 입력값으로 사용되는 것을 볼 수 있습니다.

# %% [markdown]
# ### 사전에 학습된 가중치(pretrained weight)를 불러오기

# %%
# define model and download & load pretrained weight
_DOWNLOAD_URL_PREFIX = 'http://download.tensorflow.org/models/'

model_dir = os.getenv('HOME')+'/aiffel/Exploration/E8/models'
tf.io.gfile.makedirs(model_dir)

print ('temp directory:', model_dir)

download_path = os.path.join(model_dir, 'deeplab_model.tar.gz')
if not os.path.exists(download_path):
    urllib.request.urlretrieve(_DOWNLOAD_URL_PREFIX + 'deeplabv3_mnv2_pascal_train_aug_2018_01_29.tar.gz',
                   download_path)

MODEL = DeepLabModel(download_path)
print('model loaded successfully!')
# Out:
# temp directory: /aiffel/aiffel/Exploration/E8/models
# model loaded successfully!

# %% [markdown]
# - 구글이 제공하는 deeplabv3_mnv2_pascal_train_aug_2018_01_29 weight을 다운로드하고 DeepLabModel 을 초기화합니다. 이 모델은 PASCAL VOC 2012라는 대형 데이터셋으로 학습된 v3 버전입니다.

# %% [markdown]
# ### 준비한 이미지를 네트워크에 입력

# %%
person_resized, person_seg_map = MODEL.run(person_orig)
print (person_orig.shape, person_resized.shape, person_seg_map.max())
# Out:
# (574, 430, 3) (513, 384, 3) 15

# %% [markdown]
# - cv2는 이미지를 HWC(Height, Width, Channel) 순서로 표시

# %%
# 라벨의 종류 (DeepLab은 PASCAL VOC의 라벨로 학습)
LABEL_NAMES = [
    'background', 'aeroplane', 'bicycle', 'bird', 'boat', 'bottle', 'bus',
    'car', 'cat', 'chair', 'cow', 'diningtable', 'dog', 'horse', 'motorbike',
    'person', 'pottedplant', 'sheep', 'sofa', 'train', 'tv'
]
len(LABEL_NAMES)
# Out:
# 21

# %% [markdown]
# - background를 제외하면 20개의 클래스가 있습니다. 따라서 20 의 의미는 tv 가 되겠네요! 0부터 시작하니까요.
# - person 15, cat 8

# %% [markdown]
# ### 사람(person) 라벨 (15)를 가진 영역 마스크를 만들고 시각화

# %%
person_show = person_resized.copy()
person_seg_map = np.where(person_seg_map == 15, 15, 0) # 예측 중 사람만 추출
person_mask = person_seg_map * (255/person_seg_map.max()) # 255 normalization
person_mask = person_mask.astype(np.uint8)
person_color_mask = cv2.applyColorMap(person_mask, cv2.COLORMAP_JET)
person_show = cv2.addWeighted(person_show, 0.6, person_color_mask, 0.35, 0.0)

plt.imshow(cv2.cvtColor(person_show, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# - 사람을 뜻하는 15 외 예측은 0으로 만들었습니다. 그럼 예측된 세그멘테이션 이미지(map)는 최댓값이 15가 됩니다. 일반 이미지는 0부터 255 까지의 값을 사용해 픽셀을 표현하므로, 세그멘테이션 맵에 표현된 값을 원본 이미지에 그림 형태로 출력하기 위해 255로 정규화 합니다. applyColorMap() 함수로 색을 적용하고 이미지를 화면에 출력합니다.

# %% [markdown]
# ### 3) 세그멘테이션 결과를 원래 크기로 복원하기
#
# DeepLab 모델을 사용하기 위해 이미지 크기를 작게 resize 해서 입력했습니다. 따라서 출력도 resize 된 입력 크기와 같게 나오게 됩니다.
#
# 세그멘테이션 결과(mask)를 원래 크기로 복원해 보겠습니다.

# %%
person_mask_up = cv2.resize(person_mask, person_orig.shape[:2][::-1], interpolation=cv2.INTER_LINEAR)
_, person_mask_up = cv2.threshold(person_mask_up, 128, 255, cv2.THRESH_BINARY)

ax = plt.subplot(1,2,1)
plt.imshow(person_mask_up, cmap=plt.cm.binary_r)
ax.set_title('Original Size Mask')

ax = plt.subplot(1,2,2)
plt.imshow(person_mask, cmap=plt.cm.binary_r)
ax.set_title('DeepLab Model Mask')

plt.show()

# %% [markdown]
# - cv2.resize() 함수를 이용합니다. 크기를 키울 때 보간(interpolation) 을 고려해야 하는데요,
#     cv2.INTER_NEAREST를 이용해서 깔끔하게 처리할 수 있지만 더 정확히 확대하기 위해 cv2.INTER_LINEAR 를 사용합니다.
#     여기서 보간법(interpolation)은 이미지의 크기를 변경(scaling)하는 과정에서 컴퓨터가 사이사이 픽셀값을 채우는 방법입니다.
#
#
# - 결과적으로 img_mask_up 은 경계가 블러된 픽셀값 0~255의 이미지를 얻습니다. 확실한 경계를 다시 정하기 위해 중간값인 128을 기준으로 임계값(threshold)을 설정합니다. 128 이하의 값은 0으로 128 이상의 값은 255로 만드는 방법입니다.

# %% [markdown]
# ### 4) 배경 흐리게 하기

# %%
person_orig_blur = cv2.blur(person_orig, (13,13)) #(13,13)은 blurring  kernel size를 뜻합니다. 
plt.imshow(cv2.cvtColor(person_orig_blur, cv2.COLOR_BGR2RGB))
plt.show()

# %%
# 흐려진 이미지에서 세그멘테이션 마스크를 이용해서 배경만 추출
person_mask_color = cv2.cvtColor(person_mask_up, cv2.COLOR_GRAY2BGR)
person_bg_mask = cv2.bitwise_not(person_mask_color)
person_bg_blur = cv2.bitwise_and(person_orig_blur, person_bg_mask)
plt.imshow(cv2.cvtColor(person_bg_blur, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# - bitwise_not 함수를 이용하면 이미지가 반전됩니다. 배경은 255 사람은 0이 됩니다.
#     반전된 세그멘테이션 결과를 이용해서 이미지와 bitwise_and 연산을 수행하면 배경만 있는 영상을 얻을 수 있습니다.

# %% [markdown]
# ### 5) 흐린 배경과 원본 영상 합성

# %%
person_concat = np.where(person_mask_color==255, person_orig, person_bg_blur)
plt.imshow(cv2.cvtColor(person_concat, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# - 세그멘테이션 마스크가 255인 부분만 원본 영상을 가지고 오고 반대인 영역은 블러된 미지 값을 사용합니다.
# - 인물과 배경의 거리차이가 있고 거리가 일정할 수록 더 자연스러워 보입니다.

# %% [markdown]
# ## 인물사진 모드 결과

# %%
# before & after 
ax = plt.subplot(1,2,1)
plt.imshow(cv2.cvtColor(person_orig, cv2.COLOR_BGR2RGB))
ax.set_title('Original Image')
plt.axis("off") # 축 제거

ax = plt.subplot(1,2,2)
plt.imshow(cv2.cvtColor(person_concat, cv2.COLOR_BGR2RGB))
ax.set_title('Portrait mode Image')

plt.axis("off") # 축 제거
plt.show()

# %% [markdown]
# - 인물을 제외한 배경의 블러 처리가 잘 된것을 볼 수 있다.

# %% [markdown]
# ## 2. 고양이 사진 적용해보기

# %%
# 사진 준비하기 

cat_path = os.getenv('HOME')+'/aiffel/Exploration/E8/images/cat.png' 
cat_orig = cv2.imread(cat_path) 
print (cat_orig.shape)
# Out:
# (1440, 1440, 3)

# %%
# 준비한 이미지를 네트워크에 넣기

cat_resized, cat_seg_map = MODEL.run(cat_orig)
print (cat_orig.shape, cat_resized.shape, cat_seg_map.max())
# Out:
# (1440, 1440, 3) (513, 513, 3) 12

# %%
# 고양이(cat) 라벨 (8)를 가진 영역 마스크를 만들고 시각화

cat_show = cat_resized.copy()
cat_seg_map = np.where(cat_seg_map == 8, 8, 0) # 예측 중 고양이만 추출
cat_mask = cat_seg_map * (255/cat_seg_map.max()) # 255 normalization
cat_mask = cat_mask.astype(np.uint8)
cat_color_mask = cv2.applyColorMap(cat_mask, cv2.COLORMAP_JET)
cat_show = cv2.addWeighted(cat_show, 0.6, cat_color_mask, 0.35, 0.0)

plt.imshow(cv2.cvtColor(cat_show, cv2.COLOR_BGR2RGB))
plt.show()

# %%
# 세그멘테이션 결과(mask)를 원래 크기로 복원

cat_mask_up = cv2.resize(cat_mask, cat_orig.shape[:2][::-1], interpolation=cv2.INTER_LINEAR)
_, cat_mask_up = cv2.threshold(cat_mask_up, 128, 255, cv2.THRESH_BINARY)

ax = plt.subplot(1,2,1)
plt.imshow(cat_mask_up, cmap=plt.cm.binary_r)
ax.set_title('Original Size Mask')

ax = plt.subplot(1,2,2)
plt.imshow(cat_mask, cmap=plt.cm.binary_r)
ax.set_title('DeepLab Model Mask')

plt.show()

# %%
# 배경 흐리게 하기

cat_orig_blur = cv2.blur(cat_orig, (13,13)) #(13,13)은 blurring  kernel size
plt.imshow(cv2.cvtColor(cat_orig_blur, cv2.COLOR_BGR2RGB))
plt.show()

# %%
# 흐려진 이미지에서 세그멘테이션 마스크를 이용해서 배경만 추출

cat_mask_color = cv2.cvtColor(cat_mask_up, cv2.COLOR_GRAY2BGR)
cat_bg_mask = cv2.bitwise_not(cat_mask_color)
cat_bg_blur = cv2.bitwise_and(cat_orig_blur, cat_bg_mask)
plt.imshow(cv2.cvtColor(cat_bg_blur, cv2.COLOR_BGR2RGB))
plt.show()

# %%
# 흐린 배경과 원본 사진 합성

cat_concat = np.where(cat_mask_color==255, cat_orig, cat_bg_blur)
plt.imshow(cv2.cvtColor(cat_concat, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# ## 고양이 사진 적용 결과

# %%
# before & after 

ax = plt.subplot(1,2,1)
plt.imshow(cv2.cvtColor(cat_orig, cv2.COLOR_BGR2RGB))
ax.set_title('Original Image')
plt.axis("off") # 축 제거

ax = plt.subplot(1,2,2)
plt.imshow(cv2.cvtColor(cat_concat, cv2.COLOR_BGR2RGB))
ax.set_title('Portrait mode Image')

plt.axis("off") # 축 제거
plt.show()

# %% [markdown]
# - 고양이 마스크를 적용할 때 다리 부분이 조금 잘린것을 제외하면 배경 블러 처리는 잘 된것을 확인할 수 있다.

# %% [markdown]
# ## 3. 크로마키 적용해보기

# %%
# 배경으로 사용할 이미지 가져오기 
bg_path = os.getenv('HOME')+'/aiffel/Exploration/E8/images/background.png'  
bg_orig = cv2.imread(bg_path) 

# 인물이미지와 같은 사이즈로 만들어주기
bg_resize = cv2.resize(bg_orig, person_orig.shape[:2][::-1], interpolation=cv2.INTER_LINEAR)
# img_orig.shape[:2][::-1]
# person_orig shape = (574, 430)
print (bg_resize.shape)
plt.imshow(cv2.cvtColor(bg_resize, cv2.COLOR_BGR2RGB))
# Out:
# (574, 430, 3)

# %%
# 배경 이미지에서 세그멘테이션 마스크를 이용해서 배경만 추출

bg_img = cv2.bitwise_and(bg_resize, person_bg_mask)
plt.imshow(cv2.cvtColor(bg_img, cv2.COLOR_BGR2RGB))
plt.show()

# %%
# 배경사진과 인물사진 합성

img_concat = np.where(person_mask_color==255, person_orig, bg_img)
plt.imshow(cv2.cvtColor(img_concat, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# ## 크로마키 결과

# %%
# before & after 
ax = plt.subplot(1,2,1)
plt.imshow(cv2.cvtColor(person_orig, cv2.COLOR_BGR2RGB))
ax.set_title('Original Image')
plt.axis("off") # 축 제거

ax = plt.subplot(1,2,2)
plt.imshow(cv2.cvtColor(img_concat, cv2.COLOR_BGR2RGB))
ax.set_title('Chroma Key Image')

plt.axis("off") # 축 제거
plt.show()

# %% [markdown]
# - 인물의 외형이 타이트하게 잡히지는 않았지만 배경은 잘 적용된 것을 볼 수 있다.

# %% [markdown]
# ## 4. 인물모드 사진의 문제점

# %%
# 다른 사람의 이미지 가져오기
img_path = os.getenv('HOME')+'/aiffel/Exploration/E8/images/person2.png' 
img_orig = cv2.imread(img_path)

# 준비한 이미지를 네트워크에 입력
img_resized, seg_map = MODEL.run(img_orig)

# 사람(person) 라벨 (15)를 가진 영역 마스크를 만들기
img_show = img_resized.copy()
seg_map = np.where(seg_map == 15, 15, 0) # 예측 중 사람만 추출
img_mask = seg_map * (255/seg_map.max()) # 255 normalization
img_mask = img_mask.astype(np.uint8)
color_mask = cv2.applyColorMap(img_mask, cv2.COLORMAP_JET)
img_show = cv2.addWeighted(img_show, 0.6, color_mask, 0.35, 0.0)

# 세그멘테이션 결과를 원래 크기로 복원하기
img_mask_up = cv2.resize(img_mask, img_orig.shape[:2][::-1], interpolation=cv2.INTER_LINEAR)
_, img_mask_up = cv2.threshold(img_mask_up, 128, 255, cv2.THRESH_BINARY)

# 배경 흐리게 하기
img_orig_blur = cv2.blur(img_orig, (13,13))

# 흐려진 이미지에서 세그멘테이션 마스크를 이용해서 배경만 추출
img_mask_color = cv2.cvtColor(img_mask_up, cv2.COLOR_GRAY2BGR)
img_bg_mask = cv2.bitwise_not(img_mask_color)
img_bg_blur = cv2.bitwise_and(img_orig_blur, img_bg_mask)
plt.imshow(cv2.cvtColor(img_bg_blur, cv2.COLOR_BGR2RGB))
plt.show()

# 흐린 배경과 원본 영상 합성
img_concat = np.where(img_mask_color==255, img_orig, img_bg_blur)

# %%
# before & after 
ax = plt.subplot(1,2,1)
plt.imshow(cv2.cvtColor(img_orig, cv2.COLOR_BGR2RGB))
ax.set_title('Original Image')
plt.axis("off") # 축 제거

ax = plt.subplot(1,2,2)
plt.imshow(cv2.cvtColor(img_concat, cv2.COLOR_BGR2RGB))
ax.set_title('Portrait mode Image')

plt.axis("off") # 축 제거
plt.show()

# %% [markdown]
# - 위 사진에서 핑크색 부분은 원래 인물에 포함되지 않는다.
#     하지만 이미지에서 배경만 추출한 것에서 볼 수 있듯 핑크색 부분도 사람영역 마스크에 포함되어 있다.
#
# - semantic segmentation mask의 오류를 보완할 수 있는 솔루션으로 마스크를 만든 경계 주변의 색 정보를 좀 더 정교하게 비교하며 다른 색이면 다른 클래스로 분류할 수 있다면 좋을것 같습니다.

# %% [markdown]
# # 회고
#
# - 인물모드 사진을 성공적으로 제작하였다.
#     아웃포커싱 효과가 적용된 인물모드 사진과 고양이 사진, 배경전환 크로마키사진을 각각 1장씩 성공적으로 제작하였다.
#
#
# - 제작한 인물모드 사진들에서 나타나는 문제점을 지적하였다.
#     인물사진에서 발생한 문제점을 정확히 지적한 사진을 제출하였다.
#
#
# - 인물모드 사진의  semantic segmentation mask의 오류 문제점을 개선할 수 있는 솔루션을 대략적으로 제시하였다.
